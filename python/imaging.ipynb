# %% [markdown]
# # Welcome to Jupyter!

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import random
import time

# %%
# read the CSV file, in this case with , separation

#data= pd.read_csv('DEF.csv', sep=";", header=None, names=["xs", "ys", "xr", "yr", "R"])
#data= pd.read_csv('DEF_metingen_test.csv', sep=";", header=None, names=["xs", "ys", "xr", "yr", "R"])

data = pd.DataFrame(columns=["xs", "ys", "xr", "yr", "R"], data=[
    [0,60,0,50,41.2],
    [0,50,0,40,41.2],
    [0,50,0,40,41.2],
    [0,40,0,30,41.2],
    [0,30,0,20,41.2],
    [0,60,0,40,44.6],
    [0,50,0,30,44.6],
    [0,40,0,20,44.6],
    [0,30,0,10,44.6],
    [0,60,0,30,50.0],
    [0,50,0,20,50.0],
    [0,40,0,10,50.0],
    [10,0,30,0,44.6],
    [20,0,40,0,44.6],
    [30,0,50,0,44.6],
    [40,0,60,0,44.6],
    [10,0,40,0,50.0],
    [20,0,50,0,50.0],
    [30,0,60,0,50.0]
    ])
print(data)

# assign arrays to the columns of the input
xs=data['xs']
ys=data['ys']
xr=data['xr']
yr=data['yr']
R=data['R']
# Out:
#     xs  ys  xr  yr     R
# 0    0  60   0  50  41.2
# 1    0  50   0  40  41.2
# 2    0  50   0  40  41.2
# 3    0  40   0  30  41.2
# 4    0  30   0  20  41.2
# 5    0  60   0  40  44.6
# 6    0  50   0  30  44.6
# 7    0  40   0  20  44.6
# 8    0  30   0  10  44.6
# 9    0  60   0  30  50.0
# 10   0  50   0  20  50.0
# 11   0  40   0  10  50.0
# 12  10   0  30   0  44.6
# 13  20   0  40   0  44.6
# 14  30   0  50   0  44.6
# 15  40   0  60   0  44.6
# 16  10   0  40   0  50.0
# 17  20   0  50   0  50.0
# 18  30   0  60   0  50.0

# %%
# number of points in each array
n=len(R)

# plot all these points

# define midpoints for all measurements
xm=(xs+xr)/2
ym=(ys+yr)/2

# define offset for all measurements
offset=np.sqrt((xs-xr)*(xs-xr)+(ys-yr)*(ys-yr))

# define distance from midpoint to ellipse point
d=0.5*np.sqrt(R*R-offset*offset)

# define the ellipse point from midpoint
vecx=d*(ys-yr)/offset
vecy=-d*(xs-xr)/offset

# define new figure
plt.figure()
axes = plt.gca()
axes.set_xlim([0,70])
axes.set_ylim([0,70])

# plot the ellipses
for i in range(n):
    # plot the source and receiver location
    plt.plot(xs[i],ys[i],'ro')
    plt.plot(xr[i],yr[i],'bo')
    # plot the ellipe point from the midpoint
    if (xm[i]+vecx[i])>0:
        scl=1
    else:
        scl=-1
    # plot points away from the ellipse
    teta=np.arctan2(ys[i]-yr[i],xs[i]-xr[i])
    # define array of ellipse points
    th = np.linspace(0,2*np.pi,100);
    # calculate x and y points
    x = xm[i] + 0.5*R[i]*np.cos(th)*np.cos(teta) - d[i]*np.sin(th)*np.sin(teta);
    y = ym[i] + 0.5*R[i]*np.cos(th)*np.sin(teta) + d[i]*np.sin(th)*np.cos(teta);
    plt.plot(x,y)
    # h=ellipse(xm(i),ym(i),R(i)/2,d(i),teta)
    print(teta)
    plt.pause(0.1)

# starting values of parameters and search range
x00=45
y00=45
alpha0=0.0
beta0=0.0
d_xy=30
d_angle=45

# make array for best nall values
nbest=10
x0minbest=np.zeros(nbest)
y0minbest=np.zeros(nbest)
alphaminbest=np.zeros(nbest)
betaminbest=np.zeros(nbest)
objfunminbest=np.zeros(nbest)+9999
objfunmin=9999

# eps defines weight of slopes in objfun
eps=1.0

# number of random search points
nrand=1000

# iterate over new starting points
for iter in range(10):
    # do random search around initial value
    for j in range(nrand):
        # generate random settings of the variables
        if j==1:
            x0=x00
            y0=y00
            alpha=alpha0
            beta=beta0
        else:
            fact=2*np.random.rand(4)-1.0
            x0=x00+fact[0]*d_xy
            y0=y00+fact[1]*d_xy
            alpha=alpha0+fact[2]*d_angle
            beta=beta0+fact[3]*d_angle
        #left branche
        dy=np.linspace(0,40,41)
        y1=y0+dy
        x1=x0+dy*np.tan(beta*np.pi/180)
        # right branche
        dx=np.linspace(0,40,41)
        x2=x0+dx
        y2=y0+dx*np.tan(alpha*np.pi/180)
        # distance to all points
        Dmin=np.zeros(n)
        Imin=np.zeros(n)
        slope=np.zeros(n)
        for i in range(n):
            # calculate the distances
            DR1=np.sqrt(np.square(x1-xr[i])+np.square(y1-yr[i]))
            DS1=np.sqrt(np.square(x1-xs[i])+np.square(y1-ys[i]))
            DR2=np.sqrt(np.square(x2-xr[i])+np.square(y2-yr[i]))
            DS2=np.sqrt(np.square(x2-xs[i])+np.square(y2-ys[i]))
            D1=np.abs(DR1+DS1-R[i])
            D2=np.abs(DR2+DS2-R[i])
            D1D2=np.concatenate((D1,D2), axis=0)
            Dmin[i],Imin[i] = min( (D1D2[i],i) for i in range(len(D1D2)) )
            DR=np.concatenate((DR1,DR2), axis=0)
            DS=np.concatenate((DS1,DS2), axis=0)
            ii=int(min(max(1,Imin[i]),len(DR)-2))
            slope[i]=DR[ii+1]+DS[ii+1]-DR[ii-1]-DS[ii-1]
        # determine objective function value
        D_aver=np.mean(Dmin)
        slope_aver=np.mean(abs(slope))
        objfun=D_aver+eps*slope_aver
        # check if this one is better
        if objfun<objfunmin:
            print("New minimum x0=%6.3f y0=%6.3f alpha=%6.3f beta=%6.3f" % (x0,y0,alpha,beta))
            print("D_aver=%6.3f  slope_aver=%6.3f objfun=%6.3f"% (D_aver,slope_aver,objfun))
            # plot this object
            plt.plot(x1,y1,'r')
            plt.plot(x2,y2,'r')
            plt.pause(0.1)
            # save these values
            x0min=x0
            y0min=y0
            alphamin=alpha
            betamin=beta
            # save the plotted object
            x1min=x1
            y1min=y1
            x2min=x2
            y2min=y2
            objfunmin=objfun
            time.sleep(1)
        # check if it is within the best values and unique
        if (objfun<objfunminbest[nbest-1]):
            # check which position
            k=0
            while objfun>objfunminbest[k]:
                k=k+1;
            # only accept is it is really different
            if objfun != objfunminbest[k-1]:
                print("Found better objfun value ",objfun," for position ",k)
                x0minbest[k+1:nbest-1]=x0minbest[k:nbest-2]
                x0minbest[k]=x0
                y0minbest[k+1:nbest-1]=y0minbest[k:nbest-2]
                y0minbest[k]=y0
                alphaminbest[k+1:nbest-1]=alphaminbest[k:nbest-2]
                alphaminbest[k]=alpha
                betaminbest[k+1:nbest-1]=betaminbest[k:nbest-2]
                betaminbest[k]=beta
                objfunminbest[k+1:nbest-1]=objfunminbest[k:nbest-2]
                objfunminbest[k]=objfun;
    # plot final again for this iteration
    plt.plot(x1min,y1min,'m',linewidth=2.0)
    plt.plot(x2min,y2min,'m',linewidth=2.0)
    plt.pause(0.1)
    # end of this iteration
    print("end of iteration ",iter)
    # display final result for parameters with standard deviation
    print("Best alpha= %6.2f with standard deviation= %6.2f" % (np.mean(alphaminbest),np.std(alphaminbest)))
    print("Best beta = %6.2f with standard deviation= %6.2f" % (np.mean(betaminbest),np.std(betaminbest)))
    print("Best x0   = %6.2f with standard deviation= %6.2f" % (np.mean(x0minbest),np.std(x0minbest)))
    print("Best y0   = %6.2f with standard deviation= %6.2f" % (np.mean(y0minbest),np.std(y0minbest)))
    time.sleep(1)

# define new figure te replot ellipses and optimum object
plt.figure()
axes = plt.gca()
axes.set_xlim([0,70])
axes.set_ylim([0,70])

# plot the ellipses
for i in range(n):
    # plot the source and receiver location
    plt.plot(xs[i],ys[i],'ro')
    plt.plot(xr[i],yr[i],'bo')
    # plot the ellipe point from the midpoint
    if (xm[i]+vecx[i])>0:
        scl=1
    else:
        scl=-1
    # plot points away from the ellipse
    teta=np.arctan2(ys[i]-yr[i],xs[i]-xr[i])
    # define array of ellipse points
    th = np.linspace(0,2*np.pi,100);
    # calculate x and y points
    x = xm[i] + 0.5*R[i]*np.cos(th)*np.cos(teta) - d[i]*np.sin(th)*np.sin(teta);
    y = ym[i] + 0.5*R[i]*np.cos(th)*np.sin(teta) + d[i]*np.sin(th)*np.cos(teta);
    plt.plot(x,y)
    # h=ellipse(xm(i),ym(i),R(i)/2,d(i),teta)
    print(teta)
    plt.pause(0.1)

# plot best object location
plt.plot(x1min,y1min,'k',linewidth=4.0)
plt.plot(x2min,y2min,'k',linewidth=4.0)
plt.pause(0.1)


# define new figure
plt.figure()
plt.plot(objfunminbest)
plt.pause(0.1)

input("Press Enter to finish....")
# Out:
# 1.5707963267948966
# 1.5707963267948966
# 1.5707963267948966
# 1.5707963267948966
# 1.5707963267948966
# 1.5707963267948966
# 1.5707963267948966
# 1.5707963267948966
# 1.5707963267948966
# 1.5707963267948966
# 1.5707963267948966
# 1.5707963267948966
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# New minimum x0=22.529 y0=39.843 alpha=25.647 beta= 2.918
# D_aver=20.193  slope_aver= 1.547 objfun=21.740
# Found better objfun value  21.740240956409664  for position  0
# Found better objfun value  52.191420007088496  for position  1
# Found better objfun value  56.49675002245049  for position  2
# Found better objfun value  26.286666259959624  for position  1
# New minimum x0=18.976 y0=47.759 alpha=-40.261 beta=18.463
# D_aver= 7.787  slope_aver= 1.802 objfun= 9.590
# Found better objfun value  9.589512411362048  for position  0
# Found better objfun value  55.24176018342511  for position  4
# Found better objfun value  25.90147955802768  for position  2
# Found better objfun value  16.621248139918325  for position  1
# Found better objfun value  77.2710605354817  for position  8
# Found better objfun value  11.380328400096644  for position  1
# Found better objfun value  41.29834318574142  for position  6
# Found better objfun value  68.50921951058567  for position  9
# Found better objfun value  37.78398840961981  for position  6
# New minimum x0=29.200 y0=19.513 alpha=16.629 beta=-38.369
# D_aver= 1.297  slope_aver= 2.578 objfun= 3.875
# Found better objfun value  3.8753930025668235  for position  0
# Found better objfun value  57.105075814217315  for position  9
# Found better objfun value  56.900238554913344  for position  9
# Found better objfun value  15.810910113037657  for position  3
# Found better objfun value  45.32392195523355  for position  9
# New minimum x0=27.906 y0=16.964 alpha=-42.956 beta=-28.411
# D_aver= 0.571  slope_aver= 2.919 objfun= 3.490
# Found better objfun value  3.4898314926001257  for position  0
# Found better objfun value  23.51462168351409  for position  7
# Found better objfun value  29.746775347987278  for position  9
# Found better objfun value  17.81541539281409  for position  6
# Found better objfun value  18.77657910181179  for position  7
# Found better objfun value  17.863255711456468  for position  7
# Found better objfun value  11.559571055228615  for position  4
# Found better objfun value  11.573383172813237  for position  5
# Found better objfun value  4.218109306870771  for position  2
# Found better objfun value  15.921473296984981  for position  8
# Found better objfun value  15.318405393822985  for position  7
# Found better objfun value  29.325775854576165  for position  9
# Found better objfun value  5.215372932382374  for position  3
# Found better objfun value  25.291814893345048  for position  9
# Found better objfun value  24.058510737683186  for position  9
# New minimum x0=21.100 y0=21.646 alpha=-15.995 beta=-12.827
# D_aver= 0.304  slope_aver= 1.650 objfun= 1.955
# Found better objfun value  1.9545440025244978  for position  0
# Found better objfun value  7.7982648618729975  for position  5
# Found better objfun value  23.390399371765856  for position  9
# Found better objfun value  7.230770375860044  for position  5
# Found better objfun value  9.233512578217471  for position  7
# Found better objfun value  23.137231443946252  for position  9
# Found better objfun value  11.349854091341665  for position  9
# Found better objfun value  4.20887017031535  for position  3
# Found better objfun value  5.981387600569327  for position  6
# Found better objfun value  2.8723396988700483  for position  1
# Found better objfun value  8.43267283409503  for position  9
# Found better objfun value  5.658597242781205  for position  7
# Found better objfun value  4.88491427918388  for position  6
# Found better objfun value  7.335997521773613  for position  9
# Found better objfun value  4.57428360420486  for position  6
# Found better objfun value  3.999587582239686  for position  4
# Found better objfun value  4.633335545009568  for position  8
# New minimum x0=18.700 y0=16.526 alpha=-3.141 beta= 3.639
# D_aver= 0.436  slope_aver= 1.199 objfun= 1.635
# Found better objfun value  1.6349253786519216  for position  0
# Found better objfun value  4.390311312913128  for position  8
# Found better objfun value  5.707408352538121  for position  9
# Found better objfun value  3.8268517647093443  for position  4
# Found better objfun value  2.3534006096562283  for position  2
# Found better objfun value  3.0740926652993896  for position  4
# Found better objfun value  4.262825659775868  for position  9
# Found better objfun value  3.4561904944607074  for position  5
# Found better objfun value  3.655687937840498  for position  7
# Found better objfun value  3.3279782472856816  for position  5
# Found better objfun value  2.411292983462368  for position  3
# Found better objfun value  4.0610701405870095  for position  9
# Found better objfun value  3.76560018332847  for position  9
# end of iteration  0
# Best alpha= -12.33 with standard deviation=  21.79
# Best beta = -12.56 with standard deviation=  11.01
# Best x0   =  22.48 with standard deviation=   4.19
# Best y0   =  19.82 with standard deviation=   2.68
# Found better objfun value  2.2490038450380387  for position  2
# Found better objfun value  2.3865860868491353  for position  4
# New minimum x0=15.333 y0=19.980 alpha=-2.617 beta=11.657
# D_aver= 0.414  slope_aver= 1.048 objfun= 1.463
# Found better objfun value  1.4627907112223826  for position  0
# Found better objfun value  2.9646364525091045  for position  8
# Found better objfun value  2.7279434080513703  for position  7
# Found better objfun value  3.382482161719332  for position  9
# Found better objfun value  2.544381309525199  for position  7
# Found better objfun value  2.752187239479341  for position  9
# Found better objfun value  2.3152139680606014  for position  4
# end of iteration  1
# Best alpha= -12.64 with standard deviation=  14.04
# Best beta =  -3.05 with standard deviation=   8.02
# Best x0   =  19.13 with standard deviation=   2.18
# Best y0   =  20.61 with standard deviation=   4.58
# Found better objfun value  2.5326439409724637  for position  8
# Found better objfun value  2.7088113506779363  for position  9
# Found better objfun value  2.256440286950764  for position  4
# Found better objfun value  2.3993474240557857  for position  8
# end of iteration  2
# Best alpha=  -7.27 with standard deviation=  11.17
# Best beta =   0.96 with standard deviation=   9.09
# Best x0   =  17.89 with standard deviation=   1.77
# Best y0   =  20.81 with standard deviation=   5.04
# Found better objfun value  2.328699214251807  for position  6
# Found better objfun value  2.6168560990305347  for position  9
# Found better objfun value  2.4893409863533345  for position  9
# end of iteration  3
# Best alpha=  -9.75 with standard deviation=  12.86
# Best beta =  -1.51 with standard deviation=   9.00
# Best x0   =  17.94 with standard deviation=   1.77
# Best y0   =  21.18 with standard deviation=   5.33
# Found better objfun value  1.6258290851019748  for position  1
# Found better objfun value  2.219299187922422  for position  4
# end of iteration  4
# Best alpha= -10.35 with standard deviation=  12.22
# Best beta =  -3.21 with standard deviation=   9.06
# Best x0   =  18.88 with standard deviation=   2.34
# Best y0   =  20.44 with standard deviation=   4.28
# Found better objfun value  1.8424255752377454  for position  3
# Found better objfun value  2.477405101661238  for position  9
# Found better objfun value  1.6456517033290932  for position  3
# end of iteration  5
# Best alpha=  -5.33 with standard deviation=  12.35
# Best beta =  -2.73 with standard deviation=   9.50
# Best x0   =  19.34 with standard deviation=   2.40
# Best y0   =  18.70 with standard deviation=   3.21
# Found better objfun value  1.8527763230150889  for position  5
# end of iteration  6
# Best alpha=  -6.61 with standard deviation=  12.62
# Best beta =  -3.97 with standard deviation=   8.48
# Best x0   =  19.89 with standard deviation=   2.11
# Best y0   =  19.53 with standard deviation=   3.46
# Found better objfun value  1.8306976182235006  for position  4
# end of iteration  7
# Best alpha=  -7.84 with standard deviation=  11.59
# Best beta =  -2.64 with standard deviation=   7.83
# Best x0   =  19.47 with standard deviation=   2.40
# Best y0   =  20.13 with standard deviation=   3.19
# Found better objfun value  1.7388369693873134  for position  4
# end of iteration  8
# Best alpha=  -5.12 with standard deviation=   9.27
# Best beta =  -3.14 with standard deviation=   8.33
# Best x0   =  19.55 with standard deviation=   2.50
# Best y0   =  19.50 with standard deviation=   2.78
# Found better objfun value  1.971981699784612  for position  9
# end of iteration  9
# Best alpha=  -7.68 with standard deviation=   6.01
# Best beta =  -0.95 with standard deviation=   7.84
# Best x0   =  19.08 with standard deviation=   2.62
# Best y0   =  19.68 with standard deviation=   2.54
# 1.5707963267948966
# 1.5707963267948966
# 1.5707963267948966
# 1.5707963267948966
# 1.5707963267948966
# 1.5707963267948966
# 1.5707963267948966
# 1.5707963267948966
# 1.5707963267948966
# 1.5707963267948966
# 1.5707963267948966
# 1.5707963267948966
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793
# 3.141592653589793

# %% [markdown]
# This repo contains an introduction to [Jupyter](https://jupyter.org) and [IPython](https://ipython.org).
#
# Outline of some basics:
#
# * [Notebook Basics](../examples/Notebook/Notebook%20Basics.ipynb)
# * [IPython - beyond plain python](../examples/IPython%20Kernel/Beyond%20Plain%20Python.ipynb)
# * [Markdown Cells](../examples/Notebook/Working%20With%20Markdown%20Cells.ipynb)
# * [Rich Display System](../examples/IPython%20Kernel/Rich%20Output.ipynb)
# * [Custom Display logic](../examples/IPython%20Kernel/Custom%20Display%20Logic.ipynb)
# * [Running a Secure Public Notebook Server](../examples/Notebook/Running%20the%20Notebook%20Server.ipynb#Securing-the-notebook-server)
# * [How Jupyter works](../examples/Notebook/Multiple%20Languages%2C%20Frontends.ipynb) to run code in different languages.

# %% [markdown]
# You can also get this tutorial and run it on your laptop:
#
#     git clone https://github.com/ipython/ipython-in-depth
#
# Install IPython and Jupyter:
#
# with [conda](https://www.anaconda.com/download):
#
#     conda install ipython jupyter
#
# with pip:
#
#     # first, always upgrade pip!
#     pip install --upgrade pip
#     pip install --upgrade ipython jupyter
#
# Start the notebook in the tutorial directory:
#
#     cd ipython-in-depth
#     jupyter notebook
